# %%
import pandas as pd

path = "../data/raw/mobile_de_results_all.csv"
df = pd.read_csv(path, encoding="latin-1")

df.head()
# Out:
#                                                  url  \
# 0  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 1  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 2  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 3  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 4  https://www.mobile.de/es/veh%C3%ADculos/detall...
#
#                                          title       brand              model  \
# 0                 Honda Civic para 34.990Â â¬       Honda              Civic
# 1          Toyota Proace City para 25.840Â â¬      Toyota        Proace City
# 2                   Ford Puma para 18.880Â â¬        Ford               Puma
# 3  Volkswagen Tiguan Allspace para 19.950Â â¬  Volkswagen    Tiguan Allspace
# 4       Kia cee'd Sportswagon para 20.990Â â¬         Kia  cee'd Sportswagon
#
#    price_eur      km first_registration  year blocked skipped  skip_reason
# 0    34990.0    2000            06/2025  2025   False    True  price>30000
# ...

# %%
df.shape[0]
# Out:
# 3905

# %%
df.head(20)
# Out:
#                                                   url  \
# 0   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 1   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 2   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 3   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 4   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 5   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 6   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 7   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 8   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 9   https://www.mobile.de/es/veh%C3%ADculos/detall...
# 10  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 11  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 12  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 13  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 14  https://www.mobile.de/es/veh%C3%ADculos/detall...
# 15  https://www.mobile.de/es/veh%C3%ADculos/detall...
# ...

# %%
cols = [
    "url",
    "brand",
    "model",
    "price_eur",
    "km",
    "year"
]

df_clean = df[cols].copy()

df_clean.shape
# Out:
# (3905, 6)

# %%
df_clean.head(20)
# Out:
#                                                   url          brand  \
# 0   https://www.mobile.de/es/veh%C3%ADculos/detall...          Honda
# 1   https://www.mobile.de/es/veh%C3%ADculos/detall...         Toyota
# 2   https://www.mobile.de/es/veh%C3%ADculos/detall...           Ford
# 3   https://www.mobile.de/es/veh%C3%ADculos/detall...     Volkswagen
# 4   https://www.mobile.de/es/veh%C3%ADculos/detall...            Kia
# 5   https://www.mobile.de/es/veh%C3%ADculos/detall...     Volkswagen
# 6   https://www.mobile.de/es/veh%C3%ADculos/detall...            BMW
# 7   https://www.mobile.de/es/veh%C3%ADculos/detall...     Volkswagen
# 8   https://www.mobile.de/es/veh%C3%ADculos/detall...     Volkswagen
# 9   https://www.mobile.de/es/veh%C3%ADculos/detall...     Volkswagen
# 10  https://www.mobile.de/es/veh%C3%ADculos/detall...     Volkswagen
# 11  https://www.mobile.de/es/veh%C3%ADculos/detall...            BMW
# 12  https://www.mobile.de/es/veh%C3%ADculos/detall...            BMW
# ...
